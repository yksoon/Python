# %% [markdown]
# ## 그룹 연산
# - 복잡한 데이터를 어떤 기준에 따라 여러 그룹으로 나누어서 관찰할 수 있으며 이런 방식으로 분할 처리하는 것을 그룹 연산이라 함
# - 그룹 연산은 데이터를 집계, 변환, 필터링 하는데 효율적이며 판다느 groupby() 메소드를 사용 함
# - 그룹 객체 만들기(분할)
# - 그룹 연산 메소드(적용-결합)

# %%
import pandas as pd
import seaborn as sns

# titanic 데이터셋에서 age, sex 등 5개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'sex', 'class', 'fare', 'survived']]

print('승객 수 : ', len(df))
display(df.head())
# Out:
# 승객 수 :  891
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
# class 열을 기준으로 분할(1개 열을 기준)
grouped = df.groupby(['class'])
print(grouped)
list(grouped)
# Out:
# ...
# [('First',
#         age     sex  class     fare  survived
#   1    38.0  female  First  71.2833         1
#   3    35.0  female  First  53.1000         1
#   6    54.0    male  First  51.8625         0
#   11   58.0  female  First  26.5500         1
#   23   28.0    male  First  35.5000         1
#   ..    ...     ...    ...      ...       ...
#   871  47.0  female  First  52.5542         1
#   872  33.0    male  First   5.0000         0
#   879  56.0  female  First  83.1583         1
#   887  19.0  female  First  30.0000         1
#   889  26.0    male  First  30.0000         1
#
#   [216 rows x 5 columns]),
#  ('Second',
#         age     sex   class     fare  survived
#   9    14.0  female  Second  30.0708         1
#   15   55.0  female  Second  16.0000         1
#   17    NaN    male  Second  13.0000         1
#   20   35.0    male  Second  26.0000         0
#   21   34.0    male  Second  13.0000         1
#   ..    ...     ...     ...      ...       ...
# ...

# %%
# 그룹 객체를 iteration으로 출력 : head() 메소드로 첫 5행만 출력

for key, group in grouped:
    print('* key : ', key)
    print('* number : ', len(group))
    display(group.head())
# Out:
# * key :  First
# * number :  216
#      age     sex  class     fare  survived
# 1   38.0  female  First  71.2833         1
# 3   35.0  female  First  53.1000         1
# 6   54.0    male  First  51.8625         0
# 11  58.0  female  First  26.5500         1
# 23  28.0    male  First  35.5000         1
# * key :  Second
# * number :  184
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 17   NaN    male  Second  13.0000         1
# 20  35.0    male  Second  26.0000         0
# 21  34.0    male  Second  13.0000         1
# * key :  Third
# * number :  491
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0

# %%
# 연산 메소드 적용
average = grouped.mean()
display(average)
# Out:
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# Second  29.877630  20.662183  0.472826
# Third   25.140620  13.675550  0.242363

# %%
start = grouped.max()
display(start)

end = grouped.min()
display(end)
# Out:
#          age   sex      fare  survived
# class
# First   80.0  male  512.3292         1
# Second  70.0  male   73.5000         1
# Third   74.0  male   69.5500         1
#          age     sex  fare  survived
# class
# First   0.92  female   0.0         0
# Second  0.67  female   0.0         0
# Third   0.42  female   0.0         0

# %% [markdown]
# #### Q. 'Third' 그룹만 선택해서 group3 이름으로 저장하고 통계요약표를 출력하세요.

# %%
# 개별그룹 선택하기
group1 = grouped.get_group('First')
display(group1.head())

group3 = grouped.get_group('Third')
display(group3.head())
# Out:
#      age     sex     fare  survived
# 1   38.0  female  71.2833         1
# 3   35.0  female  53.1000         1
# 6   54.0    male  51.8625         0
# 11  58.0  female  26.5500         1
# 23  28.0    male  35.5000         1
#     age     sex     fare  survived
# 0  22.0    male   7.2500         0
# 2  26.0  female   7.9250         1
# 4  35.0    male   8.0500         0
# 5   NaN    male   8.4583         0
# 7   2.0    male  21.0750         0

# %%
display(group1.describe())
display(group3.describe())
# Out:
#               age        fare    survived
# count  186.000000  216.000000  216.000000
# mean    38.233441   84.154687    0.629630
# std     14.802856   78.380373    0.484026
# min      0.920000    0.000000    0.000000
# 25%     27.000000   30.923950    0.000000
# 50%     37.000000   60.287500    1.000000
# 75%     49.000000   93.500000    1.000000
# max     80.000000  512.329200    1.000000
#               age        fare    survived
# count  355.000000  491.000000  491.000000
# mean    25.140620   13.675550    0.242363
# std     12.495398   11.778142    0.428949
# min      0.420000    0.000000    0.000000
# 25%     18.000000    7.750000    0.000000
# 50%     24.000000    8.050000    0.000000
# 75%     32.000000   15.500000    0.000000
# max     74.000000   69.550000    1.000000

# %% [markdown]
# #### Q. class열, sex 열을 기준으로 분할하여 grouped_two에 저장하세요.

# %%
# class 열, sex 열을 기준으로 분할(여러 열을 기분으로 분할)
grouped_two = df.groupby(['class', 'sex'])

# %% [markdown]
# #### Q. grouped_two 그룹 객체를 for문을 사용, interation으로 출력하세요.

# %%
# grouped_two 그룹 객체를 interation으로 출력
for key, group in grouped_two:
    print('* key:', key)
    print('* number:', len(group))
    display(group.head())
# Out:
# * key: ('First', 'female')
# * number: 94
#      age     sex  class      fare  survived
# 1   38.0  female  First   71.2833         1
# 3   35.0  female  First   53.1000         1
# 11  58.0  female  First   26.5500         1
# 31   NaN  female  First  146.5208         1
# 52  49.0  female  First   76.7292         1
# * key: ('First', 'male')
# * number: 122
#      age   sex  class      fare  survived
# 6   54.0  male  First   51.8625         0
# 23  28.0  male  First   35.5000         1
# 27  19.0  male  First  263.0000         0
# 30  40.0  male  First   27.7208         0
# 34  28.0  male  First   82.1708         0
# * key: ('Second', 'female')
# * number: 76
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 41  27.0  female  Second  21.0000         0
# 43   3.0  female  Second  41.5792         1
# 53  29.0  female  Second  26.0000         1
# * key: ('Second', 'male')
# * number: 108
# ...

# %% [markdown]
# #### Q. grouped_two 그룹 객체에 연산 메소드를 적용, 각 그룹의 편균값을 구한 후 출력하세요.

# %%
average2 = grouped_two.mean()
display(average2.head())
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000

# %% [markdown]
# #### Q. grouped_two 그룹 객체에서 ('Third', female) 그룹을 선택해서 group3f에 저장하고 처음 5개 행을 출력하세요.

# %%
group3f = grouped_two.get_group(('Third', 'female'))
display(group3f.head())
# Out:
#      age     sex  class     fare  survived
# 2   26.0  female  Third   7.9250         1
# 8   27.0  female  Third  11.1333         1
# 10   4.0  female  Third  16.7000         1
# 14  14.0  female  Third   7.8542         0
# 18  31.0  female  Third  18.0000         0

# %% [markdown]
# ## 적용 - 결합
# - 데이터 집계(agg), 변환(transform), 필터링(fillter), 객체에 함수 매핑(apply)

# %%
import pandas as pd
import seaborn as sns

# titanic 데이터 셋에서 age, sex 등 5개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'sex', 'class', 'fare', 'survived']]

# class 열을 기준으로 분할
grouped = df.groupby(['class'])

# %%
# 각 그룹에 대한 모든 열의 표준편차를 집계하여 데이터프레임으로 반환
std_all = grouped.std()
display(std_all)
print()
print(type(std_all))
# Out:
#               age       fare  survived
# class
# First   14.802856  78.380373  0.484026
# Second  14.001077  13.417399  0.500623
# Third   12.495398  11.778142  0.428949
# <class 'pandas.core.frame.DataFrame'>

# %%
# 각 그룹에 대한 fare 열의 표준편차를 집계하여 시리즈로 반환
std_fare = grouped.fare.std()
display(std_fare)
print()
print(type(std_fare))
# Out:
# class
# First     78.380373
# Second    13.417399
# Third     11.778142
# Name: fare, dtype: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #### Q. 최대값 - 최소값을 반환하는 사용자 함수를 정의하고 agg() 함수에 인수로 전달하여 그룹별로 집계하여 agg_minmax 이름으로 저장 후 처음 5개 행을 출력하세요.

# %%
# 그룹 객체에 agg() 메소드 적용 - 사용자 정의 함수를 인수로 전달
def min_max(x):
    return x.max() - x.min()

# 각 그룹의 최대값과 최소값의 차이를 계산하여 그룹별로 집계
agg_minmax = grouped.agg(min_max)
display(agg_minmax.head())
# Out:
#           age      fare  survived
# class
# First   79.08  512.3292         1
# Second  69.33   73.5000         1
# Third   73.58   69.5500         1

# %%
# 여러 함수를 각 열에 동일하게 적용하여 집계
agg_all = grouped.agg(['min', 'max'])
display(agg_all.head())
# Out:
#          age           sex       fare           survived
#          min   max     min   max  min       max      min max
# class
# First   0.92  80.0  female  male  0.0  512.3292        0   1
# Second  0.67  70.0  female  male  0.0   73.5000        0   1
# Third   0.42  74.0  female  male  0.0   69.5500        0   1

# %% [markdown]
# #### Q. grouped에 각 열마다 다른 함수를 적용하여 agg_sep 이름으로 저장하고 출력하세요.
# ('fare'는 'min', 'max','age'는 'maen')

# %%
# 각 열마다 다른 함수를 적용하여 집계
agg_sep = grouped.agg({'fare':['min', 'max'], 'age':'mean'})
display(agg_sep.head())
# Out:
#        fare                  age
#         min       max       mean
# class
# First   0.0  512.3292  38.233441
# Second  0.0   73.5000  29.877630
# Third   0.0   69.5500  25.140620

# %%
import pandas as pd
import seaborn as sns

# titanic 데이터 셋에서 age, sex 등 5개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'sex', 'class', 'fare', 'survived']]

# class열을 기준으로 분할
grouped = df.groupby(['class'])

# %% [markdown]
# #### Q. 데이터 개수가 200개 이상인 그룹만을 필터링 하여 데이터프레임으로 반환하여 grouped_filter이름으로 저장 후 처음 5개 행을 출력하세요

# %%
grouped_filter = grouped.filter(lambda x : len(x) >= 200)

display(grouped_filter.head())
print()
print(type(grouped_filter))
# Out:
#     age     sex     fare  survived
# 0  22.0    male   7.2500         0
# 1  38.0  female  71.2833         1
# 2  26.0  female   7.9250         1
# 3  35.0  female  53.1000         1
# 4  35.0    male   8.0500         0
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Q. age열의 평균이 30보다 작은 그룹만을 필터링하여 데이터프레임으로 반환하여 age_filter 이름으로 저장 후 끝에서 5개행을 출력하세요.

# %%
age_filter = grouped.filter(lambda x : x.age.mean() < 30)

display(age_filter.head())
print()
print(type(age_filter))
# Out:
#     age     sex     fare  survived
# 0  22.0    male   7.2500         0
# 2  26.0  female   7.9250         1
# 4  35.0    male   8.0500         0
# 5   NaN    male   8.4583         0
# 7   2.0    male  21.0750         0
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Q. CLASS 각 그룹별 요약 통계정보를 집계 출력 하세요.
# - 소스 : sns.load_dataset('titanic')
# - 컬럼 선택 : ['age', 'sex', 'class', 'fare', 'survived']

# %%
import pandas as pd
import seaborn as sns

# titanic 데이터 셋에서 age, sex 등 5개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'sex', 'class', 'fare', 'survived']]
grouped = df.groupby(['class'])

# 집계
agg_grouped = grouped.apply(lambda x : x.describe())
display(agg_grouped)
# Out:
#                      age        fare    survived
# class
# First  count  186.000000  216.000000  216.000000
#        mean    38.233441   84.154687    0.629630
#        std     14.802856   78.380373    0.484026
#        min      0.920000    0.000000    0.000000
#        25%     27.000000   30.923950    0.000000
#        50%     37.000000   60.287500    1.000000
#        75%     49.000000   93.500000    1.000000
#        max     80.000000  512.329200    1.000000
# Second count  173.000000  184.000000  184.000000
#        mean    29.877630   20.662183    0.472826
#        std     14.001077   13.417399    0.500623
#        min      0.670000    0.000000    0.000000
#        25%     23.000000   13.000000    0.000000
#        50%     29.000000   14.250000    0.000000
#        75%     36.000000   26.000000    1.000000
#        max     70.000000   73.500000    1.000000
# Third  count  355.000000  491.000000  491.000000
#        mean    25.140620   13.675550    0.242363
# ...

# %%
# z - score 를 계산하는 사용자 함수 정의
def z_score(x):
    return (x-x.mean()) / x.std()

age_zscore = grouped.age.apply(z_score)
print(age_zscore.head())
# Out:
# 0   -0.251342
# 1   -0.015770
# 2    0.068776
# 3   -0.218434
# 4    0.789041
# Name: age, dtype: float64

# %%
# 필터링 : age 열의 데이터 평균이 30보다 작은 그룹만을 필터링하여 출력
age_filter = grouped.apply(lambda x : x.age.mean() < 30)
print(age_filter)
print()

for x in age_filter.index:
    if age_filter[x] == True:
        age_filter_df = grouped.get_group(x)
        print(age_filter_df.head())
        print()
# Out:
# class
# First     False
# Second     True
# Third      True
# dtype: bool
#
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 17   NaN    male  Second  13.0000         1
# 20  35.0    male  Second  26.0000         0
# 21  34.0    male  Second  13.0000         1
#
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0

# %%
import pandas as pd
import seaborn as sns

# titanic 데이터 셋에서 age, sex 등 5개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'sex', 'class', 'fare', 'survived']]

# class열, sex열을 기준으로 분할
grouped = df.groupby(['class', 'sex'])

# %%
# 그룹 객체에 연산 메서드 적용
gdf = grouped.mean()
display(gdf)
print()
print(type(gdf))
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Q. class값이 First인 행을 선택하여 출력하세요.

# %%
display(gdf.loc['First'])
# Out:
#               age        fare  survived
# sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %% [markdown]
# #### Q. class값이 First이고, sex값이 female인 행을 선택하여 출력하세요.

# %%
display(gdf.loc['First', 'female'])
# Out:
# age          34.611765
# fare        106.125798
# survived      0.968085
# Name: (First, female), dtype: float64

# %% [markdown]
# #### Q. sex값이 male인 행을 선택하여 출력하세요.

# %%
print(gdf.xs('male', level='sex'))
# Out:
#               age       fare  survived
# class
# First   41.281386  67.226127  0.368852
# Second  30.740707  19.741782  0.157407
# Third   26.507589  12.661633  0.135447

# %% [markdown]
# ## 피벗
# - 피벗 테이블을 구성하는 4가지 요소(행 인덱스, 열 인덱스, 데이터 값, 데이터 집계함수)에 적용할 데이터프레임의 열을 각각 지정하여 함수의 인자로 전달

# %%
import pandas as pd
import seaborn as sns

# IPython 디스플레이 설정 변경
pd.set_option('display.max_columns', 10)   # 출력할 최대 열의 개수
pd.set_option('display.max_colwidth', 20)   # 출력할 열의 너비

# titanic 데이터 셋에서 age, sex 등 5개 열을 선택하여 데이터프레임 만들기
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'sex', 'class', 'fare', 'survived']]

display(df.head())
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
# 행, 열, 값, 집계에 사용할 열을 1개씩 지정 - 평균 집계
pdf1 = pd.pivot_table(df,                # 피벗 할 데이터프레임
                     index = 'class',    # 행 위치에 들어갈 열
                     columns = 'sex',    # 열 위치에 들어갈 열
                     values = 'age',     # 데이터로 사용할 열
                     aggfunc = 'mean')   # 데이터 집계 함수
display(pdf1.head())
# Out:
# sex        female       male
# class
# First   34.611765  41.281386
# Second  28.722973  30.740707
# Third   21.750000  26.507589

# %% [markdown]
# #### Q. 값에 적용하는 집계함수를 2개 이상 지정 할 수 있다. 'mean', 'sum'을 지정하여 출력하세요

# %%
pdf2 = pd.pivot_table(df,                # 피벗 할 데이터프레임
                     index = 'class',    # 행 위치에 들어갈 열
                     columns = 'sex',    # 열 위치에 들어갈 열
                     values = 'age',     # 데이터로 사용할 열
                     aggfunc = ['mean', 'sum'])   # 데이터 집계 함수
display(pdf2.head())
# Out:
#              mean                sum
# sex        female       male  female     male
# class
# First   34.611765  41.281386  2942.0  4169.42
# Second  28.722973  30.740707  2125.5  3043.33
# Third   21.750000  26.507589  2218.5  6706.42

# %% [markdown]
# #### Q. 행, 열, 값에 사용할 열을 2개 이상 지정할 수 있다. index, values, aggfunc에 각각 2개를 지정하여 출력하세요.

# %%
pdf3 = pd.pivot_table(df,                # 피벗 할 데이터프레임
                     index = ['class', 'sex'],    # 행 위치에 들어갈 열
                     columns = 'survived',    # 열 위치에 들어갈 열
                     values = ['age', 'fare'],     # 데이터로 사용할 열
                     aggfunc = ['mean', 'max'])   # 데이터 집계 함수
display(pdf3.head())
# Out:
#                     mean                                      max        \
#                      age                   fare               age
# survived               0          1           0           1     0     1
# class  sex
# First  female  25.666667  34.939024  110.604167  105.978159  50.0  63.0
#        male    44.581967  36.248000   62.894910   74.637320  71.0  80.0
# Second female  36.000000  28.080882   18.250000   22.288989  57.0  55.0
#        male    33.369048  16.022000   19.488965   21.095100  70.0  62.0
# Third  female  23.818182  19.329787   19.773093   12.464526  48.0  63.0
#
#
#                  fare
# survived            0         1
# class  sex
# First  female  151.55  512.3292
#        male    263.00  512.3292
# Second female   26.00   65.0000
#        male     73.50   39.0000
# Third  female   69.55   31.3875

# %% [markdown]
# ###### Q. pdf3 에서 xs인덱서를 사용하여 다음사항을 수행 후 출력하세요.
# - 행 인덱스가 First인 행을 선택
# - 행 인덱스가 ('First', 'female')인 행을 선택
# - 행 인덱스의 sex 레벨이 male인 행을 선택
# - Second, male인 행을 선택
# - 열 인덱스가('mean', 'age')인 데이터 선택
# - survived 레벨이 1인 데이터 선택
# - max, fare, survived=0인 데이터 선택
